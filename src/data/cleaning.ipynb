# %%
import pandas as pd

# %%
#Read CSV File
df = pd.read_csv('./pokemon_initial.csv')
df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# 0                  Bulbasaur     Grass    Poison    318   45      49       49
# 1                    Ivysaur     Grass    Poison    405   60      62       63
# 2                   Venusaur     Grass    Poison    525   80      82       83
# 3     Venusaur Mega Venusaur     Grass    Poison    625   80     100      123
# 4                 Charmander      Fire       NaN    309   39      52       43
# ...                      ...       ...       ...    ...  ...     ...      ...
# 1189            Iron Valiant     Fairy  Fighting    590   74     130       90
# 1190                Koraidon  Fighting    Dragon    670  100     135      115
# 1191                Miraidon  Electric    Dragon    670  100      85      100
# 1192            Walking Wake     Water    Dragon    590   99      83       91
# 1193             Iron Leaves     Grass   Psychic    590   90     130       88
#
#       Sp. Atk  Sp. Def  Speed
# 0          65       65     45
# 1          80       80     60
# 2         100      100     80
# 3         122      120     80
# 4          60       50     65
# ...       ...      ...    ...
# 1189      120       60    116
# 1190       85      100    135
# 1191      135      115    135
# 1192      125       83    109
# 1193       70      108    104
#
# [1194 rows x 13 columns]

# %%
# Remove any rows that might be duplicates
df = df.drop_duplicates()
df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# 0                  Bulbasaur     Grass    Poison    318   45      49       49
# 1                    Ivysaur     Grass    Poison    405   60      62       63
# 2                   Venusaur     Grass    Poison    525   80      82       83
# 3     Venusaur Mega Venusaur     Grass    Poison    625   80     100      123
# 4                 Charmander      Fire       NaN    309   39      52       43
# ...                      ...       ...       ...    ...  ...     ...      ...
# 1189            Iron Valiant     Fairy  Fighting    590   74     130       90
# 1190                Koraidon  Fighting    Dragon    670  100     135      115
# 1191                Miraidon  Electric    Dragon    670  100      85      100
# 1192            Walking Wake     Water    Dragon    590   99      83       91
# 1193             Iron Leaves     Grass   Psychic    590   90     130       88
#
#       Sp. Atk  Sp. Def  Speed
# 0          65       65     45
# 1          80       80     60
# 2         100      100     80
# 3         122      120     80
# 4          60       50     65
# ...       ...      ...    ...
# 1189      120       60    116
# 1190       85      100    135
# 1191      135      115    135
# 1192      125       83    109
# 1193       70      108    104
#
# [1194 rows x 13 columns]

# %%
# Remove unused column
df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#                                               image_url    Id  \
# 0     https://img.pokemondb.net/sprites/sword-shield...     1
# 1     https://img.pokemondb.net/sprites/sword-shield...     2
# 2     https://img.pokemondb.net/sprites/sword-shield...     3
# 3     https://img.pokemondb.net/sprites/sword-shield...     3
# 4     https://img.pokemondb.net/sprites/sword-shield...     4
# ...                                                 ...   ...
# 1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# 0                  Bulbasaur     Grass    Poison    318   45      49       49
# 1                    Ivysaur     Grass    Poison    405   60      62       63
# 2                   Venusaur     Grass    Poison    525   80      82       83
# 3     Venusaur Mega Venusaur     Grass    Poison    625   80     100      123
# 4                 Charmander      Fire       NaN    309   39      52       43
# ...                      ...       ...       ...    ...  ...     ...      ...
# 1189            Iron Valiant     Fairy  Fighting    590   74     130       90
# 1190                Koraidon  Fighting    Dragon    670  100     135      115
# 1191                Miraidon  Electric    Dragon    670  100      85      100
# 1192            Walking Wake     Water    Dragon    590   99      83       91
# 1193             Iron Leaves     Grass   Psychic    590   90     130       88
#
#       Sp. Atk  Sp. Def  Speed
# 0          65       65     45
# 1          80       80     60
# 2         100      100     80
# 3         122      120     80
# 4          60       50     65
# ...       ...      ...    ...
# 1189      120       60    116
# 1190       85      100    135
# 1191      135      115    135
# 1192      125       83    109
# 1193       70      108    104
#
# [1194 rows x 12 columns]

# %%
df = df.dropna()

# Reset the index of the DataFrame
df = df.reset_index(drop=True)
df
# Out:
#                                              image_url    Id  \
# 0    https://img.pokemondb.net/sprites/sword-shield...     1
# 1    https://img.pokemondb.net/sprites/sword-shield...     2
# 2    https://img.pokemondb.net/sprites/sword-shield...     3
# 3    https://img.pokemondb.net/sprites/sword-shield...     3
# 4    https://img.pokemondb.net/sprites/sword-shield...     6
# ..                                                 ...   ...
# 647  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 648  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 649  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 650  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 651  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                       Names     Type1     Type2  Total   HP  Attack  Defense  \
# 0                 Bulbasaur     Grass    Poison    318   45      49       49
# 1                   Ivysaur     Grass    Poison    405   60      62       63
# 2                  Venusaur     Grass    Poison    525   80      82       83
# 3    Venusaur Mega Venusaur     Grass    Poison    625   80     100      123
# 4                 Charizard      Fire    Flying    534   78      84       78
# ..                      ...       ...       ...    ...  ...     ...      ...
# 647            Iron Valiant     Fairy  Fighting    590   74     130       90
# 648                Koraidon  Fighting    Dragon    670  100     135      115
# 649                Miraidon  Electric    Dragon    670  100      85      100
# 650            Walking Wake     Water    Dragon    590   99      83       91
# 651             Iron Leaves     Grass   Psychic    590   90     130       88
#
#      Sp. Atk  Sp. Def  Speed
# 0         65       65     45
# 1         80       80     60
# 2        100      100     80
# 3        122      120     80
# 4        109       85    100
# ..       ...      ...    ...
# 647      120       60    116
# 648       85      100    135
# 649      135      115    135
# 650      125       83    109
# 651       70      108    104
#
# [652 rows x 12 columns]

# %%
# # Replace non-numeric rows with empty (NaN or '') with 'Unknown'
# df["Type1"].fillna("Unknown", inplace=True)
# df["Type2"].fillna("Unknown", inplace=True)
# df["image_url"].fillna("Unknown", inplace=True)
# df["Names"].fillna("Unknown", inplace=True)

# # Fill missing values in numeric columns with median of that column
# numeric_columns = ["Total", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
# df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

# # Reset the index of the DataFrame
# df.reset_index(drop=True, inplace=True)


# df
# Out:
#                                               image_url    Id  \
# 0     https://img.pokemondb.net/sprites/sword-shield...     1
# 1     https://img.pokemondb.net/sprites/sword-shield...     2
# 2     https://img.pokemondb.net/sprites/sword-shield...     3
# 3     https://img.pokemondb.net/sprites/sword-shield...     3
# 4     https://img.pokemondb.net/sprites/sword-shield...     4
# ...                                                 ...   ...
# 1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# 0                  Bulbasaur     Grass    Poison    318   45      49       49
# 1                    Ivysaur     Grass    Poison    405   60      62       63
# 2                   Venusaur     Grass    Poison    525   80      82       83
# 3     Venusaur Mega Venusaur     Grass    Poison    625   80     100      123
# 4                 Charmander      Fire   Unknown    309   39      52       43
# ...                      ...       ...       ...    ...  ...     ...      ...
# 1189            Iron Valiant     Fairy  Fighting    590   74     130       90
# 1190                Koraidon  Fighting    Dragon    670  100     135      115
# 1191                Miraidon  Electric    Dragon    670  100      85      100
# 1192            Walking Wake     Water    Dragon    590   99      83       91
# 1193             Iron Leaves     Grass   Psychic    590   90     130       88
#
#       Sp. Atk  Sp. Def  Speed
# 0          65       65     45
# 1          80       80     60
# 2         100      100     80
# 3         122      120     80
# 4          60       50     65
# ...       ...      ...    ...
# 1189      120       60    116
# 1190       85      100    135
# 1191      135      115    135
# 1192      125       83    109
# 1193       70      108    104
#
# [1194 rows x 12 columns]

# %%
# Put cleaned data in it's own csv 
df.to_csv("pokemon.csv", index=False)
